# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from PIL import Image

DIR = './run_style_transfer/'
image_name = 'result-00099.jpg'

img = Image.open(os.path.join(DIR, image_name))
print(img.size)

img_arr = np.asarray(img)
# %matplotlib inline
imshow(img_arr)
# Out:
# (224, 224)

# %%
image_name1 = 'result-00005.jpg'

img = Image.open(os.path.join(DIR, image_name1))
print(img.size)

img_arr = np.asarray(img)
# %matplotlib inline
imshow(img_arr)
# Out:
# (224, 224)
